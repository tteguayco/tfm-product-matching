# %% [markdown]
# <div>
#     <img src="http://www.uoc.edu/portal/_resources/common/imatges/marca_UOC/UOC_Masterbrand.jpg" ,="" align="left">
# </div>
# <div style="float: right; width: 50%;">
# <p style="margin: 0; padding-top: 22px; text-align:right;">End-of-degree Project: Product Matching</p>
# <p style="margin: 0; text-align:right;">Master's Degree in Data Science</p>
# <p style="margin: 0; text-align:right; padding-button: 100px;">Computer Science, Multimedia and Telecommunication studies</p>
# </div>

# %% [markdown]
# <h1>Data cleansing</h1>
#
# <hr/>
#
# In this Notebook...

# %%
import pandas as pd

# %%
PRODUCT_DATA_FINAL_PATH = '../RawData/ProductDataFinal.csv'
ROWS_TO_SHOW = 5

df = pd.read_csv(PRODUCT_DATA_FINAL_PATH)

print("Initial number of products (rows): {}".format(df.shape[0]))
print("Initial number of attributes (columns): {}".format(df.shape[1]))
# Out:
# Initial number of products (rows): 300000
# Initial number of attributes (columns): 35

# %%
# Pick only relevent columns
df = df.loc[:,
    [
        'WebShopName',
        'WebShopProductID',
        'BrandName',
        #'Name',
        'Price',
        'Currency',
        'Color',
        'ProdanetID'
    ]]

# Define columns type
df['WebShopName'] = df['WebShopName'].astype('category')
df['WebShopProductID'] = df['WebShopProductID'].astype('category')
df['BrandName'] = df['BrandName'].astype('category')
#df['Name'] = df['Name'].astype('category')
df['Price'] = df['Price'].astype('float')
df['Currency'] = df['Currency'].astype('category')
df['Color'] = df['Color'].astype('category')
df['ProdanetID'] = df['ProdanetID'].astype('category')

# Shuffle the dataset
df = df.sample(frac=1)

# %%
df.head(ROWS_TO_SHOW)
# Out:
#                   WebShopName WebShopProductID BrandName   Price Currency  \
# 71690   Amazon-Marketplace.de       B000025T35       NaN   11.09      EUR
# 27372               Amazon.de       B0006ZQ8SW       NaN    7.51      EUR
# 91881             Mandrops.de       B017HASGUG    Hasbro   15.88      EUR
# 170761                 JPC.de          8726491       NaN   16.99      EUR
# 36376        Technikdirekt.de           355770       AEG  429.00      EUR
#
#        Color ProdanetID
# 71690    NaN    1761579
# 27372    NaN    1758975
# 91881    NaN    1395681
# 170761   NaN    2015321
# 36376    NaN    1612859

# %%
df.describe(include = 'all')
# Out:
#        WebShopName WebShopProductID BrandName          Price Currency  \
# count       300000           300000    195240  300000.000000   300000
# unique         796           197240      1851            NaN        3
# top      Amazon.de          5893697      Hama            NaN      EUR
# freq         75985             1321     48915            NaN   296714
# mean           NaN              NaN       NaN     140.111458      NaN
# std            NaN              NaN       NaN     813.964903      NaN
# min            NaN              NaN       NaN       0.010000      NaN
# 25%            NaN              NaN       NaN      12.780000      NaN
# 50%            NaN              NaN       NaN      19.990000      NaN
# 75%            NaN              NaN       NaN      67.652500      NaN
# max            NaN              NaN       NaN  299505.000000      NaN
#
#            Color  ProdanetID
# count       7864    300000.0
# unique      1865    161023.0
# top     schwarz    1845671.0
# freq         660      1322.0
# mean         NaN         NaN
# std          NaN         NaN
# min          NaN         NaN
# 25%          NaN         NaN
# 50%          NaN         NaN
# 75%          NaN         NaN
# max          NaN         NaN

# %% [markdown]
# ///////////////////////////////////////////

# %%
from sklearn.tree import DecisionTreeRegressor
import numpy as np


X = df.loc[:, df.columns != 'ProdanetID'].values.tolist()
y = df.loc[:, df.columns == 'ProdanetID'].values.tolist()

clf = DecisionTreeRegressor()
clf.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-8af06fd1b906> in <module>()
#       7
#       8 clf = tree.DecisionTreeClassifier()
# ----> 9 clf.fit(X, y)
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     788             sample_weight=sample_weight,
#     789             check_input=check_input,
# --> 790             X_idx_sorted=X_idx_sorted)
#     791         return self
#     792
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     114         random_state = check_random_state(self.random_state)
#     115         if check_input:
# --> 116             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     117             y = check_array(y, ensure_2d=False, dtype=None)
#     118             if issparse(X):
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# ValueError: could not convert string to float: 'Amazon-Marketplace.de'
